# %%
import pandas as pd

# %%
csv_file = "mass_shootings.csv"
mass_shootings_df = pd.read_csv(csv_file)
mass_shootings_df.head()
# Out:
#                                 case                location        date  \
# 0  Uvalde elementary school massacre           Uvalde, Texas   5/24/2022
# 1       Buffalo supermarket massacre       Buffalo, New York   5/14/2022
# 2  Sacramento County church shooting  Sacramento, California   2/28/2022
# 3        Oxford High School shooting        Oxford, Michigan  11/30/2021
# 4              San Jose VTA shooting    San Jose, California   5/26/2021
#
#                                              summary  fatalities injured  \
# 0                                    DETAILS PENDING          15       -
# 1  Payton S. Gendron, 18, committed a racially mo...          10       3
# 2  "A man believed to be meeting his three childr...           4       0
# 3  Ethan Crumbley, a 15-year-old student at Oxfor...           4       7
# 4  Samuel Cassidy, 57, a Valley Transportation Au...           9       0
#
#   total_victims location.1 age_of_shooter prior_signs_mental_health_issues  \
# 0             -     School             18                                -
# 1            13  workplace             18                              yes
# 2             4  Religious              -                                -
# 3            11     School             15                                -
# 4             9  Workplace             57                              yes
#
#    ...                        weapon_details   race gender  \
# 0  ...                                     -      -      M
# 1  ...  Bushmaster XM-15 semiautomatic rifle  White      M
# 2  ...                                     -      -      M
# 3  ...                  Sig Sauer 9mm pistol      -      M
# 4  ...                                     -      -      M
#
#                                              sources  \
# 0  https://abcnews.go.com/US/texas-elementary-sch...
# 1  https://www.nytimes.com/live/2022/05/15/nyregi...
# 2  https://www.nytimes.com/2022/02/28/us/church-s...
# 3  https://www.washingtonpost.com/nation/2021/11/...
# 4  https://www.sfchronicle.com/crime/article/Mass...
#
#                                mental_health_sources sources_additional_age  \
# 0                                                  -                      -
# 1  https://www.nytimes.com/2022/05/15/nyregion/gu...                      -
# 2                                                  -                      -
# 3                                                  -                      -
# 4  https://www.nytimes.com/2021/05/26/us/what-hap...                      -
#
#       latitude     longitude  type  year
# 0            -             -  Mass  2022
# 1            -             -  Mass  2022
# 2  38.60111019  -121.4189659  Mass  2022
# 3  42.84410784  -83.25992831  Mass  2021
# 4    37.316097   -121.888533  Mass  2021
#
# [5 rows x 24 columns]

# %%
mass_shootings_df["state"] = mass_shootings_df["location"].apply(lambda x:x.split(",")[1])
mass_shootings_df.head()
# Out:
#                                 case                location        date  \
# 0  Uvalde elementary school massacre           Uvalde, Texas   5/24/2022
# 1       Buffalo supermarket massacre       Buffalo, New York   5/14/2022
# 2  Sacramento County church shooting  Sacramento, California   2/28/2022
# 3        Oxford High School shooting        Oxford, Michigan  11/30/2021
# 4              San Jose VTA shooting    San Jose, California   5/26/2021
#
#                                              summary  fatalities injured  \
# 0                                    DETAILS PENDING          15       -
# 1  Payton S. Gendron, 18, committed a racially mo...          10       3
# 2  "A man believed to be meeting his three childr...           4       0
# 3  Ethan Crumbley, a 15-year-old student at Oxfor...           4       7
# 4  Samuel Cassidy, 57, a Valley Transportation Au...           9       0
#
#   total_victims location.1 age_of_shooter prior_signs_mental_health_issues  \
# 0             -     School             18                                -
# 1            13  workplace             18                              yes
# 2             4  Religious              -                                -
# 3            11     School             15                                -
# 4             9  Workplace             57                              yes
#
#    ...   race gender                                            sources  \
# 0  ...      -      M  https://abcnews.go.com/US/texas-elementary-sch...
# 1  ...  White      M  https://www.nytimes.com/live/2022/05/15/nyregi...
# 2  ...      -      M  https://www.nytimes.com/2022/02/28/us/church-s...
# 3  ...      -      M  https://www.washingtonpost.com/nation/2021/11/...
# 4  ...      -      M  https://www.sfchronicle.com/crime/article/Mass...
#
#                                mental_health_sources sources_additional_age  \
# 0                                                  -                      -
# 1  https://www.nytimes.com/2022/05/15/nyregion/gu...                      -
# 2                                                  -                      -
# 3                                                  -                      -
# 4  https://www.nytimes.com/2021/05/26/us/what-hap...                      -
#
#       latitude     longitude  type  year        state
# 0            -             -  Mass  2022        Texas
# 1            -             -  Mass  2022     New York
# 2  38.60111019  -121.4189659  Mass  2022   California
# 3  42.84410784  -83.25992831  Mass  2021     Michigan
# 4    37.316097   -121.888533  Mass  2021   California
#
# [5 rows x 25 columns]

# %%
ms_df = mass_shootings_df[["state","year","summary"]]
ms_df
# Out:
#            state  year                                            summary
# 0          Texas  2022                                    DETAILS PENDING
# 1       New York  2022  Payton S. Gendron, 18, committed a racially mo...
# 2     California  2022  "A man believed to be meeting his three childr...
# 3       Michigan  2021  Ethan Crumbley, a 15-year-old student at Oxfor...
# 4     California  2021  Samuel Cassidy, 57, a Valley Transportation Au...
# ..           ...   ...                                                ...
# 123      Florida  1987  Retired librarian William Cruse, 59, was paran...
# 124     Oklahoma  1986  Postal worker Patrick Sherrill, 44, opened fir...
# 125   California  1984  James Oliver Huberty, 41, opened fire in a McD...
# 126        Texas  1984  Abdelkrim Belachheb, 39, opened fire at an ups...
# 127      Florida  1982  Junior high school teacher Carl Robert Brown, ...
#
# [128 rows x 3 columns]

# %%
summary_ms = ms_df.groupby(["state","year"]).count()

# %%
summary_ms.value_counts()
# Out:
# summary
# 1          106
# 2            8
# 3            2
# dtype: int64

# %%
summary_ms.head()
# Out:
#                   summary
# state       year
#  Arizona    2011        1
#  Arkansas   1998        1
#  California 1984        1
#             1988        1
#             1989        1
